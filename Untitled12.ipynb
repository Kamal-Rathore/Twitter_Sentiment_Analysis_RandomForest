# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4
# !pip install textblob
# Out:
# Requirement already satisfied: spacy in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (3.7.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (41.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (2.7.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: jinja2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: language-data>=1.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from jinja2->spacy) (2.1.4)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: jinja2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: setuptools in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (41.2.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.1)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: language-data>=1.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.4)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\Dell\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from beautifulsoup4) (2.5)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: textblob in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from nltk>=3.8->textblob) (1.3.2)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from nltk>=3.8->textblob) (4.66.2)
# Requirement already satisfied: click in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/twitter_sentiment.csv', header=None, index_col=[0])
df = df[[2,3]].reset_index(drop=True)
df.columns = ['sentiment', 'text']
df.head()
# Out:
#   sentiment                                               text
# 0  Positive  im getting on borderlands and i will murder yo...
# 1  Positive  I am coming to the borders and I will kill you...
# 2  Positive  im getting on borderlands and i will kill you ...
# 3  Positive  im coming on borderlands and i will murder you...
# 4  Positive  im getting on borderlands 2 and i will murder ...

# %%
df.info()

df.isnull().sum()

df.dropna(inplace=True)

df = df[df['text'].apply(len)>1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75682 entries, 0 to 75681
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  75682 non-null  object
#  1   text       74996 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative      22530
# Positive      20844
# Neutral       18285
# Irrelevant    12988
# Name: count, dtype: int64

# %%
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\dell\appdata\local\temp\pip-req-build-e8gjmumt
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 96bf02872d9756f29d6cddb8aafaedcd2a39bbb4
# Building wheels for collected packages: preprocess-kgptalkie
#   Building wheel for preprocess-kgptalkie (setup.py): started
#   Building wheel for preprocess-kgptalkie (setup.py): finished with status 'done'
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7682 sha256=59eb6f34b8ce70f0ce53cefb748e19187373c4f0224c6a96ce07c3f6dfc13f60
#   Stored in directory: C:\Users\Dell\AppData\Local\Temp\pip-ephem-wheel-cache-n3zf78bs\wheels\fd\71\47\e04f208ad659a295ccb69022e14de7d20ccc6fc30a5a935f09
# Successfully built preprocess-kgptalkie
# Installing collected packages: preprocess-kgptalkie
#   Attempting uninstall: preprocess-kgptalkie
#     Found existing installation: preprocess-kgptalkie 0.1.3
#     Uninstalling preprocess-kgptalkie-0.1.3:
#       Successfully uninstalled preprocess-kgptalkie-0.1.3
# Successfully installed preprocess-kgptalkie-0.1.3
#   Running command git clone -q https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\Dell\AppData\Local\Temp\pip-req-build-e8gjmumt'
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
import preprocess_kgptalkie as ps

# %%
df = ps.get_basic_features(df)

# %%
df.columns
# Out:
# Index(['sentiment', 'text', 'char_counts', 'word_counts', 'avg_wordlength',
#        'stopwords_counts', 'hashtag_counts', 'mentions_counts',
#        'digits_counts', 'uppercase_counts'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))

num_cols = df.select_dtypes(include='number').columns

for col in num_cols:
    plt.subplot(2,4, num_cols.get_loc(col)+1)

    # use sentiment as hue to see the distribution of each numerical feature
    # sns.distplot(df[col], label=col, color='red')
    # sns.histplot(x=col, hue='sentiment', data=df, color='green', bins=100, kde=True)
    sns.kdeplot(data=df, x=col, hue='sentiment', fill=True)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from wordcloud) (3.7.5)
# Requirement already satisfied: pillow in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (4.49.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'C:\users\dell\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
df['sentiment'].value_counts().plot(kind='pie', autopct='%1.0f%%')

# word cloud
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)

# %%
plt.figure(figsize=(40,20))

for index, col in enumerate(df['sentiment'].unique()):
    plt.subplot(2,2, index+1)
    # print(col)
    df1 = df[df['sentiment']==col]
    data = df1['text']
    wordcloud = WordCloud(background_color='white', stopwords=stopwords, max_words=500, max_font_size=40, scale=5).generate(str(data))
    # fig = plt.figure(figsize=(15,15))
    # plt.axis('off')
    # disable ticks
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wordcloud)
    plt.title(col, fontsize=40)
    
plt.show()
plt.tight_layout()

# %%
df['text'] = df['text'].apply(lambda x: x.lower())
df['text'] = df['text'].apply(lambda x: ps.remove_urls(x))
df['text'] = df['text'].apply(lambda x: ps.remove_html_tags(x))
df['text'] = df['text'].apply(lambda x: ps.remove_special_chars(x))
df['text'] = df['text'].apply(lambda x: ps.remove_rt(x))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((59717,), (14930,))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
clf= Pipeline([('tfidf', TfidfVectorizer(stop_words='english')), ('clf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words='english')),
#                 ('clf', RandomForestClassifier(n_jobs=-1))])

# %%
from sklearn.metrics import accuracy_score

predictions = clf.predict(X_test)
print(accuracy_score(y_test, predictions))
# Out:
# 0.9058271935699933

# %%
from sklearn.metrics import classification_report

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.95      0.85      0.90      2616
#     Negative       0.92      0.93      0.92      4552
#      Neutral       0.92      0.89      0.90      3679
#     Positive       0.85      0.94      0.89      4083
#
#     accuracy                           0.91     14930
#    macro avg       0.91      0.90      0.90     14930
# weighted avg       0.91      0.91      0.91     14930

# %%
import pickle

pickle.dump(clf, open('twitter_sentiment.pkl', 'wb'))
